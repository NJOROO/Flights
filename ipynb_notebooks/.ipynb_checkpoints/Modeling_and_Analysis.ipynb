# %%
import pandas as pd
import numpy as np
import zipfile

# %%
#Due to limited memory of the machine (you can ignore this)
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df


def import_data(file):
    """create a dataframe and optimize its memory usage"""
    df = pd.read_csv(file, parse_dates=True, keep_date_col=True)
    df = reduce_mem_usage(df)
    return df

# %%
flights = pd.read_csv('Flights.zip',compression='zip')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1928/351852567.py in <module>
# ----> 1 flights = pd.read_csv('Flights.zip',compression='zip')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     678                     raise ValueError(f"Zero files found in ZIP file {path_or_buf}")
#     679                 else:
# --> 680                     raise ValueError(
#     681                         "Multiple files found in ZIP file. "
#     682                         f"Only one file per ZIP: {zip_names}"
#
# ValueError: Multiple files found in ZIP file. Only one file per ZIP: ['Origin_and_Destination_Survey_DB1BMarket_2021_1.csv', 'readme.html']

# %%
reduce_mem_usage(flights)
# Out:
# Memory usage of dataframe is 160.74 MB
# Memory usage after optimization is: 128.38 MB
# Decreased by 20.1%
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 4        2020-04-24 19:16:21 UTC  2294584263154074236  2273948316817424439
# ...                          ...                  ...                  ...
# 2633516  2020-11-21 10:10:01 UTC  2388440981134693942  1515966223526602848
# 2633517  2020-11-21 10:10:13 UTC  2388440981134693943  1515966223509089282
# 2633518  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509089917
# 2633519  2020-11-21 10:10:30 UTC  2388440981134693944  2273948184839454837
# 2633520  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509127566
#
#           category_id                category_code     brand       price  \
# 0        2.268105e+18           electronics.tablet   samsung  162.000000
# 1        2.268105e+18           electronics.tablet   samsung  162.000000
# 2        2.268105e+18  electronics.audio.headphone    huawei   77.500000
# 3        2.268105e+18  electronics.audio.headphone    huawei   77.500000
# 4        2.268105e+18                          NaN   karcher  217.625000
# ...               ...                          ...       ...         ...
# 2633516  2.268105e+18       electronics.smartphone      oppo  138.875000
# 2633517  2.268105e+18       electronics.smartphone     apple  419.000000
# 2633518  2.268105e+18   appliances.personal.scales     vitek   12.476562
# 2633519  2.268105e+18                          NaN  moulinex   41.625000
# 2633520  2.268105e+18   appliances.kitchen.blender   redmond   53.218750
#
#               user_id
# 0        1.515916e+18
# 1        1.515916e+18
# 2        1.515916e+18
# 3        1.515916e+18
# 4        1.515916e+18
# ...               ...
# 2633516  1.515916e+18
# 2633517  1.515916e+18
# 2633518  1.515916e+18
# 2633519  1.515916e+18
# 2633520  1.515916e+18
#
# [2633521 rows x 8 columns]

# %%
#flights['Dest'].value_counts()
flights.columns
# Out:
# Index(['ItinID', 'MktID', 'MktCoupons', 'Year', 'Quarter', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'Origin', 'OriginCountry',
#        'OriginStateFips', 'OriginState', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'Dest',
#        'DestCountry', 'DestStateFips', 'DestState', 'DestStateName', 'DestWac',
#        'AirportGroup', 'WacGroup', 'TkCarrierChange', 'TkCarrierGroup',
#        'OpCarrierChange', 'OpCarrierGroup', 'RPCarrier', 'TkCarrier',
#        'OpCarrier', 'BulkFare', 'Passengers', 'MktFare', 'MktDistance',
#        'MktDistanceGroup', 'MktMilesFlown', 'NonStopMiles', 'ItinGeoType',
#        'MktGeoType', 'Unnamed: 41'],
#       dtype='object')

# %%
flights['OpCarrier'].value_counts()
# Out:
# WN    1379050
# 99    1359448
# AA     921918
# DL     881212
# UA     568273
# OO     261014
# B6     230183
# AS     192560
# YX     171007
# NK     161005
# G4     147653
# F9     111229
# OH      90550
# MQ      88157
# 9E      87853
# YV      67982
# HA      53474
# QX      38603
# G7      20696
# C5      18671
# PT      17784
# ZW      17489
# SY      16550
# MX      10679
# 3M       4052
# XP       3731
# --        933
# 9K         43
# KG         25
# LF         25
# 9X         23
# 4B         15
# AC         11
# SK          4
# BR          4
# OZ          1
# 7H          1
# FI          1
# LH          1
# Name: OpCarrier, dtype: int64

# %%
flights = flights[['Quarter', 'Origin', 'OriginWac', 'Dest', 'DestWac', 'MktDistance', 'Passengers' , 'OpCarrier' , 'MktFare' ]]
flights
# Out:
#          Quarter Origin  OriginWac Dest  DestWac  MktDistance  Passengers  \
# 0              4    BOS         13  BUF       22        482.0         2.0
# 1              4    BOS         13  BUF       22        482.0         1.0
# 2              4    BOS         13  BUF       22        482.0         2.0
# 3              4    BOS         13  BUF       22        482.0         1.0
# 4              4    BOS         13  BUF       22        482.0         1.0
# ...          ...    ...        ...  ...      ...          ...         ...
# 6921905        4    SFO         91  JNU        1       1588.0         1.0
# 6921906        4    JNU          1  SFO       91       1588.0         1.0
# 6921907        4    SFO         91  JNU        1       1588.0         1.0
# 6921908        4    JNU          1  SFO       91       1588.0         1.0
# 6921909        4    SFO         91  JNU        1       1588.0         1.0
#
#         OpCarrier  MktFare
# 0              99    132.0
# 1              UA    155.0
# 2              UA    162.0
# 3              99    172.0
# 4              99    182.0
# ...           ...      ...
# 6921905        AS    151.0
# 6921906        AS    151.0
# 6921907        AS    269.0
# 6921908        AS    269.0
# 6921909        AS    362.0
#
# [6921910 rows x 9 columns]

# %%
origin = 'DFW'
dest = 'ORD'

miles_df =flights[(flights['Origin'] == origin) & (flights['Dest'] == dest)]
miles_df['MktDistance']
# Out:
# 109415     1529.0
# 109416     1529.0
# 110710     2122.0
# 110724     2092.0
# 110725     2092.0
#             ...
# 6286508     801.0
# 6309363     801.0
# 6312599    1747.0
# 6312891     801.0
# 6680540     801.0
# Name: MktDistance, Length: 3879, dtype: float16

# %%
flights.dtypes
# Out:
# Quarter            int8
# Origin         category
# OriginWac          int8
# Dest           category
# DestWac            int8
# MktDistance     float16
# Passengers      float16
# OpCarrier      category
# MktFare         float32
# dtype: object

# %% [markdown]
# # PART 1 — Begin data analytics by evaluating data distribution.

# %% [markdown]
# ### 1.1) Are there any null values anywhere?

# %%
flights.isnull().sum()
# Out:
# Quarter        0
# Origin         0
# OriginWac      0
# Dest           0
# DestWac        0
# MktDistance    0
# Passengers     0
# OpCarrier      0
# MktFare        0
# dtype: int64

# %% [markdown]
# ### 1.2) What's the distribution/frequency of ['NumTicketsOrdered']?

# %% [markdown]
# ### 1.3) What's the distribution/frequency of ['AirlineCompany']?

# %%
flights['OpCarrier'].value_counts()
# Out:
# WN    1379050
# 99    1359448
# AA     921918
# DL     881212
# UA     568273
# OO     261014
# B6     230183
# AS     192560
# YX     171007
# NK     161005
# G4     147653
# F9     111229
# OH      90550
# MQ      88157
# 9E      87853
# YV      67982
# HA      53474
# QX      38603
# G7      20696
# C5      18671
# PT      17784
# ZW      17489
# SY      16550
# MX      10679
# 3M       4052
# XP       3731
# --        933
# 9K         43
# KG         25
# LF         25
# 9X         23
# 4B         15
# AC         11
# SK          4
# BR          4
# OZ          1
# 7H          1
# FI          1
# LH          1
# Name: OpCarrier, dtype: int64

# %% [markdown]
# The (12) Remaining Airline Companies After Data Refinement. These 2-letter codes are from the Department of Transportation's [Bureau of Transportation Statistics](https://www.transtats.bts.gov/Tables.asp?DB_ID=125&DB_Name=Airline%20Origin%20and%20Destination%20Survey%20%28DB1B%29&DB_Short_Name=Origin%20and%20Destination%20Survey) --
# * WN --	Southwest Airlines Co.
# * DL --	Delta Air Lines Inc.
# * AA --	American Airlines Inc.
# * UA --	United Air Lines Inc.
# * B6 --	JetBlue Airways
# * AS --	Alaska Airlines Inc.
# * NK --	Spirit Air Lines
# * G4 --	Allegiant Air
# * F9 --	Frontier Airlines Inc.
# * HA --	Hawaiian Airlines Inc.
# * SY --	Sun Country Airlines d/b/a MN Airlines
# * VX --	Virgin America

# %% [markdown]
# ### 1.4) What's the distribution/frequency of ['PricePerTicket']?

# %%
flights['MktFare'].describe()
# Out:
# count    6.921910e+06
# mean     2.312990e+02
# std      4.970865e+02
# min      0.000000e+00
# 25%      1.240000e+02
# 50%      1.915300e+02
# 75%      2.895000e+02
# max      1.223400e+06
# Name: MktFare, dtype: float64

# %% [markdown]
# ### 1.5) What's the distribution/frequency of ['Miles']?

# %%
import seaborn as sns
y2 = flights['MktDistance']
sns.distplot(y2)
# Out:
# C:\Users\MELLOW\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MktDistance', ylabel='Density'>

# %% [markdown]
# ### 1.6) What's the spread of PricePerTicket vs. Miles?

# %%
import matplotlib.pyplot as plt
plt.scatter(flights['MktFare'], flights['MktDistance'])

# %% [markdown]
# ### 1.7) Set aside lists of AirlineCompany values, Dest values, and Origin values for using in user interface web app later

# %%
airlinecompanies = sorted(list(flights['OpCarrier'].unique()))

# %%
origins = sorted(list(flights['Origin'].unique()))

# %%
destinations = sorted(list(flights['Dest'].unique()))

# %%
len(origins)
# Out:
# 435

# %%
flights.dtypes
# Out:
# Quarter            int8
# Origin         category
# OriginWac          int8
# Dest           category
# DestWac            int8
# MktDistance     float16
# Passengers      float16
# OpCarrier      category
# MktFare         float32
# dtype: object

# %%
flights = flights.drop(columns = ['OriginWac','DestWac'])
flights
# Out:
#          Quarter Origin Dest  MktDistance  Passengers OpCarrier  MktFare
# 0              4    BOS  BUF        482.0         2.0        99    132.0
# 1              4    BOS  BUF        482.0         1.0        UA    155.0
# 2              4    BOS  BUF        482.0         2.0        UA    162.0
# 3              4    BOS  BUF        482.0         1.0        99    172.0
# 4              4    BOS  BUF        482.0         1.0        99    182.0
# ...          ...    ...  ...          ...         ...       ...      ...
# 6921905        4    SFO  JNU       1588.0         1.0        AS    151.0
# 6921906        4    JNU  SFO       1588.0         1.0        AS    151.0
# 6921907        4    SFO  JNU       1588.0         1.0        AS    269.0
# 6921908        4    JNU  SFO       1588.0         1.0        AS    269.0
# 6921909        4    SFO  JNU       1588.0         1.0        AS    362.0
#
# [6921910 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(flights, train_size = 0.70, test_size = 0.30, random_state=42)

train, val = train_test_split(train, train_size = 0.50, test_size = 0.50, random_state=42)

train.shape, val.shape, test.shape
# Out:
# ((2422668, 7), (2422669, 7), (2076573, 7))

# %%
target = ['MktFare']
features = flights.columns.drop(target)

x_train = train[features]
y_train = train[target]

x_val = val[features]
y_val = val[target]

x_test = test[features]
y_test = test[target]

# %%
from sklearn.pipeline import make_pipeline
from category_encoders import TargetEncoder
from category_encoders import OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor

pipeline = make_pipeline(
    OrdinalEncoder(),
    RandomForestRegressor(max_depth=20, n_estimators=20)
)

pipeline.fit(x_train, y_train)
# Out:
# C:\Users\MELLOW\anaconda3\lib\site-packages\sklearn\pipeline.py:335: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# Pipeline(steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=['Origin', 'Dest', 'OpCarrier'],
#                                 mapping=[{'col': 'Origin',
#                                           'data_type': CategoricalDtype(categories=['ABE', 'ABI', 'ABQ', 'ABR', 'ABY', 'ACK', 'ACT', 'ACV',
#                   'ACY', 'ADK',
#                   ...
#                   'VLD', 'VPS', 'VQS', 'WRG', 'WYS', 'XNA', 'XWA', 'YAK',
#                   'YKM', 'YUM'],
# , ordered=False),
#                                           'mapping': CID      1
# FAI      2
# DEN      3
# ORD      4
# AZA      5
#       ...
# MCE    428
# LNY    429
# MKT    430
# MCN    431
# NaN...
#                   'KG', 'LF', 'LH', 'MQ', 'MX', 'NK', 'OH', 'OO', 'OZ', 'PT',
#                   'QX', 'SK', 'SY', 'UA', 'WN', 'XP', 'YV', 'YX', 'ZW'],
# , ordered=False),
#                                           'mapping': 99      1
# DL      2
# AA      3
# G4      4
# HA      5
# WN      6
# UA      7
# OO      8
# F9      9
# 9E     10
# C5     11
# YX     12
# NK     13
# AS     14
# OH     15
# ZW     16
# MX     17
# B6     18
# MQ     19
# YV     20
# PT     21
# QX     22
# G7     23
# SY     24
# XP     25
# 3M     26
# --     27
# 9K     28
# LF     29
# AC     30
# 9X     31
# KG     32
# BR     33
# 4B     34
# SK     35
# NaN    -2
# dtype: int64}])),
#                 ('randomforestregressor',
#                  RandomForestRegressor(max_depth=20, n_estimators=20))])

# %%
from sklearn.metrics import r2_score
y_pred = pipeline.predict(x_val)
print('RandomForest R^2 Score = ', r2_score(y_val, y_pred))
# Out:
# RandomForest R^2 Score =  0.009977210183937935

# %%
# Encode the categoricals
encoder = OrdinalEncoder()
x_train_encoded = encoder.fit_transform(x_train)
x_val_encoded = encoder.fit_transform(x_val)
x_test_encoded = encoder.fit_transform(x_test)

# %%
# LinearRegression Model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
model2 = LinearRegression()
model2.fit(x_train_encoded, y_train)
y_pred2 = model2.predict(x_val_encoded)
print('LinearRegression R² Score = ', r2_score(y_val, y_pred2))
# Out:
# LinearRegression R² Score =  0.006033748680004725

# %%
#RidgeRegression Model
from sklearn.linear_model import Ridge
model3 = Ridge()
model3.fit(x_train_encoded, y_train)
y_pred3 = model3.predict(x_val_encoded)
print('RidgeRegression R² Score = ', r2_score(y_val, y_pred3))
# Out:
# RidgeRegression R² Score =  0.006033748682481299

# %%
# Get feature importances
model = pipeline.named_steps['randomforestregressor']
importances = pd.Series(model.feature_importances_, features)

# Plot feature importances
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,6), facecolor = '#b4b4b4')
ax.set(facecolor='#b4b4b4')
#plt.title('Feature Importances for 2018 Flights Data (Target: PricePerTicket)')
n=12
importances.sort_values()[-n:].plot.barh(color='#24ccff');

# %%
from pdpbox.pdp import pdp_isolate, pdp_plot

# %%
feature4 = 'MktDistance'

isolated4 = pdp_isolate(
    model=model, 
    dataset=x_val_encoded, 
    model_features=x_val.columns, 
    feature=feature4
)

pdp_plot(isolated4, feature_name=feature4, plot_lines=True, frac_to_plot=100)
# Out:
# (<Figure size 1080x684 with 2 Axes>,
#  {'title_ax': <AxesSubplot:>, 'pdp_ax': <AxesSubplot:xlabel='MktDistance'>})

# %%
from joblib import dump
dump(pipeline, 'pipeline.joblib', compress=9)
# Out:
# ['pipeline.joblib']

# %%
pipeline_encoder = pipeline.named_steps['ordinalencoder']
mapping = pipeline_encoder.mapping

origin_dict = dict(mapping[0])
dest_dict = mapping[1]
airline_dict = mapping[2]

# %%
origin_dict['mapping'].index[0]
# Out:
# 'CID'

# %%
pd.Series.to_json(origin_dict['mapping'])
# Out:
# '{"CID":1,"FAI":2,"DEN":3,"ORD":4,"AZA":5,"PDX":6,"MSY":7,"LAS":8,"LAX":9,"TPA":10,"IDA":11,"IND":12,"FLL":13,"MCO":14,"CLT":15,"BNA":16,"AEX":17,"DFW":18,"JFK":19,"IAH":20,"ONT":21,"MSP":22,"SNA":23,"DTW":24,"BOI":25,"GCK":26,"RNO":27,"MCI":28,"SYR":29,"RDU":30,"LGA":31,"SJC":32,"PIT":33,"OKC":34,"HOU":35,"BWI":36,"GRR":37,"AUS":38,"BTR":39,"BOS":40,"DCA":41,"SEA":42,"BET":43,"SAN":44,"OGG":45,"PHL":46,"BDL":47,"STL":48,"PVD":49,"RDM":50,"SDF":51,"TYS":52,"HDN":53,"ALB":54,"SLC":55,"PIA":56,"SFO":57,"XNA":58,"ABQ":59,"CHS":60,"OMA":61,"MKE":62,"COS":63,"TXK":64,"CLE":65,"PHX":66,"PBI":67,"ILM":68,"MIA":69,"AMA":70,"RIC":71,"CMH":72,"EWR":73,"BIL":74,"LYH":75,"ISP":76,"MSN":77,"MAF":78,"SMF":79,"TLH":80,"CRW":81,"APN":82,"DAL":83,"ATL":84,"BLI":85,"PSC":86,"LAN":87,"EUG":88,"BUF":89,"MFR":90,"HNL":91,"BZN":92,"TUS":93,"JAX":94,"STX":95,"LEX":96,"RSW":97,"VPS":98,"PWM":99,"EVV":100,"GSP":101,"LIT":102,"ROC":103,"MDW":104,"PNS":105,"ELP":106,"OAK":107,"SAT":108,"IAD":109,"SJU":110,"MHT":111,"ORF":112,"KOA":113,"SPI":114,"EYW":115,"AGS":116,"GSO":117,"BFL":118,"ORH":119,"ICT":120,"AVL":121,"MOB":122,"MEM":123,"ABE":124,"FWA":125,"SBP":126,"SGF":127,"MSO":128,"LGB":129,"DAY":130,"ANC":131,"TTN":132,"BUR":133,"RAP":134,"SRQ":135,"LIH":136,"LFT":137,"ATW":138,"JAN":139,"MFE":140,"FAT":141,"CVG":142,"BHM":143,"AVP":144,"PSP":145,"BTV":146,"GUM":147,"SGU":148,"PGD":149,"TUL":150,"SAV":151,"FLG":152,"STT":153,"MGM":154,"SCE":155,"CHA":156,"LBB":157,"MDT":158,"FAY":159,"AKN":160,"RDD":161,"SHV":162,"FAR":163,"BGR":164,"GEG":165,"YUM":166,"HSV":167,"OAJ":168,"STS":169,"ACV":170,"DSM":171,"MHK":172,"GJT":173,"CAE":174,"ITO":175,"MQT":176,"MYR":177,"DAB":178,"LCH":179,"TRI":180,"FNT":181,"SIT":182,"GRB":183,"GFK":184,"MLU":185,"BRO":186,"SBN":187,"JNU":188,"FCA":189,"SBA":190,"HRL":191,"FSD":192,"MLI":193,"JAC":194,"ELM":195,"CHO":196,"ECP":197,"GPT":198,"PIE":199,"EAU":200,"ADQ":201,"COU":202,"CWA":203,"TVC":204,"LWS":205,"ITH":206,"AZO":207,"CRP":208,"SFB":209,"BMI":210,"TYR":211,"MRY":212,"UIN":213,"JST":214,"HPN":215,"PAE":216,"BLV":217,"SUX":218,"MBS":219,"PIR":220,"LNK":221,"BTM":222,"MOT":223,"CMX":224,"ASE":225,"DRO":226,"PAH":227,"OME":228,"DLG":229,"KTN":230,"RFD":231,"PVU":232,"YAK":233,"ABY":234,"HTS":235,"CPR":236,"FSM":237,"MTJ":238,"ALW":239,"MLB":240,"DEC":241,"DLH":242,"HVN":243,"SAF":244,"BQN":245,"EWN":246,"GRK":247,"GRI":248,"XWA":249,"HLN":250,"TOL":251,"CAK":252,"LAW":253,"LRD":254,"GTF":255,"ERI":256,"LSE":257,"CMI":258,"BIS":259,"EGE":260,"FNL":261,"ROA":262,"PUB":263,"COD":264,"LBL":265,"ILG":266,"BGM":267,"SWF":268,"CLL":269,"PBG":270,"USA":271,"IMT":272,"GNV":273,"ACT":274,"CDC":275,"SBY":276,"ABI":277,"FLO":278,"ROW":279,"RIW":280,"ACY":281,"EKO":282,"BHB":283,"OWB":284,"RST":285,"LBE":286,"EAT":287,"PLN":288,"BFF":289,"LBF":290,"PHF":291,"OTH":292,"HHH":293,"GGG":294,"CSG":295,"SPN":296,"LAR":297,"CIU":298,"BQK":299,"PGV":300,"BRD":301,"PSE":302,"ESC":303,"DIK":304,"ATY":305,"DHN":306,"SHR":307,"SUN":308,"SMX":309,"PSM":310,"HIB":311,"TWF":312,"VCT":313,"GCC":314,"IAG":315,"CYS":316,"LWB":317,"ACK":318,"JMS":319,"LCK":320,"BPT":321,"PUW":322,"EAR":323,"PIB":324,"DRT":325,"SJT":326,"ABR":327,"JHM":328,"MBL":329,"DDC":330,"SCK":331,"PKB":332,"ART":333,"VLD":334,"JLN":335,"MCW":336,"PPG":337,"DVL":338,"TBN":339,"GUC":340,"RHI":341,"WRG":342,"GTR":343,"DBQ":344,"HYS":345,"CGI":346,"AUG":347,"PGA":348,"MEI":349,"YKM":350,"SWO":351,"PRC":352,"CKB":353,"PQI":354,"STC":355,"OGS":356,"SPS":357,"IPL":358,"VEL":359,"BJI":360,"RKS":361,"CNY":362,"CDV":363,"HOB":364,"HGR":365,"PSG":366,"PIH":367,"SHD":368,"BIH":369,"OGD":370,"MVY":371,"TVF":372,"BFD":373,"LEB":374,"IRK":375,"BRW":376,"MKG":377,"SLN":378,"ADK":379,"WYS":380,"MWA":381,"INL":382,"HYA":383,"CDR":384,"FOD":385,"OTZ":386,"TEX":387,"RKD":388,"VQS":389,"ALS":390,"ALO":391,"HOT":392,"MSL":393,"BKW":394,"CEZ":395,"MGW":396,"RUT":397,"TUP":398,"HRO":399,"SCC":400,"CPX":401,"IWD":402,"CNM":403,"MAZ":404,"PVC":405,"SLK":406,"AIA":407,"MSS":408,"GDV":409,"AOO":410,"CVN": ...

# %%
{'label': 'Southwest Airline Co. (WN)', 'value': 2},
# Out:
# ({'label': 'Southwest Airline Co. (WN)', 'value': 2},)

# %%
origin_string_dict = ''
for row in origin_dict['mapping']:
    origin_string_dict += ("{")
    origin_string_dict += (f"'label': '{origin_dict['mapping'].index[row]}', 'value': {origin_dict['mapping'][row]}")
    origin_string_dict += ("}, ")

# %%
origin_string_dict
# Out:
# "{'label': 'FAI', 'value': 2}, {'label': 'DEN', 'value': 3}, {'label': 'ORD', 'value': 4}, {'label': 'AZA', 'value': 5}, {'label': 'PDX', 'value': 6}, {'label': 'MSY', 'value': 7}, {'label': 'LAS', 'value': 8}, {'label': 'LAX', 'value': 9}, {'label': 'TPA', 'value': 10}, {'label': 'IDA', 'value': 11}, {'label': 'IND', 'value': 12}, {'label': 'FLL', 'value': 13}, {'label': 'MCO', 'value': 14}, {'label': 'CLT', 'value': 15}, {'label': 'BNA', 'value': 16}, {'label': 'AEX', 'value': 17}, {'label': 'DFW', 'value': 18}, {'label': 'JFK', 'value': 19}, {'label': 'IAH', 'value': 20}, {'label': 'ONT', 'value': 21}, {'label': 'MSP', 'value': 22}, {'label': 'SNA', 'value': 23}, {'label': 'DTW', 'value': 24}, {'label': 'BOI', 'value': 25}, {'label': 'GCK', 'value': 26}, {'label': 'RNO', 'value': 27}, {'label': 'MCI', 'value': 28}, {'label': 'SYR', 'value': 29}, {'label': 'RDU', 'value': 30}, {'label': 'LGA', 'value': 31}, {'label': 'SJC', 'value': 32}, {'label': 'PIT', 'value': 33}, {'label': 'OKC', 'value': 34}, {'label': 'HOU', 'value': 35}, {'label': 'BWI', 'value': 36}, {'label': 'GRR', 'value': 37}, {'label': 'AUS', 'value': 38}, {'label': 'BTR', 'value': 39}, {'label': 'BOS', 'value': 40}, {'label': 'DCA', 'value': 41}, {'label': 'SEA', 'value': 42}, {'label': 'BET', 'value': 43}, {'label': 'SAN', 'value': 44}, {'label': 'OGG', 'value': 45}, {'label': 'PHL', 'value': 46}, {'label': 'BDL', 'value': 47}, {'label': 'STL', 'value': 48}, {'label': 'PVD', 'value': 49}, {'label': 'RDM', 'value': 50}, {'label': 'SDF', 'value': 51}, {'label': 'TYS', 'value': 52}, {'label': 'HDN', 'value': 53}, {'label': 'ALB', 'value': 54}, {'label': 'SLC', 'value': 55}, {'label': 'PIA', 'value': 56}, {'label': 'SFO', 'value': 57}, {'label': 'XNA', 'value': 58}, {'label': 'ABQ', 'value': 59}, {'label': 'CHS', 'value': 60}, {'label': 'OMA', 'value': 61}, {'label': 'MKE', 'value': 62}, {'label': 'COS', 'value': 63}, {'label': 'TXK', 'value': 64}, {'label': 'CLE', 'value': 65}, {'label': 'PHX', 'value': 66}, {'label': 'PBI', 'value': 67}, {'label': 'ILM', 'value': 68}, {'label': 'MIA', 'value': 69}, {'label': 'AMA', 'value': 70}, {'label': 'RIC', 'value': 71}, {'label': 'CMH', 'value': 72}, {'label': 'EWR', 'value': 73}, {'label': 'BIL', 'value': 74}, {'label': 'LYH', 'value': 75}, {'label': 'ISP', 'value': 76}, {'label': 'MSN', 'value': 77}, {'label': 'MAF', 'value': 78}, {'label': 'SMF', 'value': 79}, {'label': 'TLH', 'value': 80}, {'label': 'CRW', 'value': 81}, {'label': 'APN', 'value': 82}, {'label': 'DAL', 'value': 83}, {'label': 'ATL', 'value': 84}, {'label': 'BLI', 'value': 85}, {'label': 'PSC', 'value': 86}, {'label': 'LAN', 'value': 87}, {'label': 'EUG', 'value': 88}, {'label': 'BUF', 'value': 89}, {'label': 'MFR', 'value': 90}, {'label': 'HNL', 'value': 91}, {'label': 'BZN', 'value': 92}, {'label': 'TUS', 'value': 93}, {'label': 'JAX', 'value': 94}, {'label': 'STX', 'value': 95}, {'label': 'LEX', 'value': 96}, {'label': 'RSW', 'value': 97}, {'label': 'VPS', 'value': 98}, {'label': 'PWM', 'value': 99}, {'label': 'EVV', 'value': 100}, {'label': 'GSP', 'value': 101}, {'label': 'LIT', 'value': 102}, {'label': 'ROC', 'value': 103}, {'label': 'MDW', 'value': 104}, {'label': 'PNS', 'value': 105}, {'label': 'ELP', 'value': 106}, {'label': 'OAK', 'value': 107}, {'label': 'SAT', 'value': 108}, {'label': 'IAD', 'value': 109}, {'label': 'SJU', 'value': 110}, {'label': 'MHT', 'value': 111}, {'label': 'ORF', 'value': 112}, {'label': 'KOA', 'value': 113}, {'label': 'SPI', 'value': 114}, {'label': 'EYW', 'value': 115}, {'label': 'AGS', 'value': 116}, {'label': 'GSO', 'value': 117}, {'label': 'BFL', 'value': 118}, {'label': 'ORH', 'value': 119}, {'label': 'ICT', 'value': 120}, {'label': 'AVL', 'value': 121}, {'label': 'MOB', 'value': 122}, {'label': 'MEM', 'value': 123}, {'label': 'ABE', 'value': 124}, {'label': 'FWA', 'value': 125}, {'label': 'SBP', 'value': 126}, {'label': 'SGF', 'value': 127}, {'label': 'MSO', 'value': 128}, {'label': 'LGB', 'value': 129}, {'label': ...

# %%
origin_string2_dict = '{'
for row in origin_dict['mapping']:
    origin_string2_dict += (f"{origin_dict['mapping'][row]}: '{origin_dict['mapping'].index[row]}', ")

# %%
origin_string2_dict
# Out:
# "{2: 'FAI', 3: 'DEN', 4: 'ORD', 5: 'AZA', 6: 'PDX', 7: 'MSY', 8: 'LAS', 9: 'LAX', 10: 'TPA', 11: 'IDA', 12: 'IND', 13: 'FLL', 14: 'MCO', 15: 'CLT', 16: 'BNA', 17: 'AEX', 18: 'DFW', 19: 'JFK', 20: 'IAH', 21: 'ONT', 22: 'MSP', 23: 'SNA', 24: 'DTW', 25: 'BOI', 26: 'GCK', 27: 'RNO', 28: 'MCI', 29: 'SYR', 30: 'RDU', 31: 'LGA', 32: 'SJC', 33: 'PIT', 34: 'OKC', 35: 'HOU', 36: 'BWI', 37: 'GRR', 38: 'AUS', 39: 'BTR', 40: 'BOS', 41: 'DCA', 42: 'SEA', 43: 'BET', 44: 'SAN', 45: 'OGG', 46: 'PHL', 47: 'BDL', 48: 'STL', 49: 'PVD', 50: 'RDM', 51: 'SDF', 52: 'TYS', 53: 'HDN', 54: 'ALB', 55: 'SLC', 56: 'PIA', 57: 'SFO', 58: 'XNA', 59: 'ABQ', 60: 'CHS', 61: 'OMA', 62: 'MKE', 63: 'COS', 64: 'TXK', 65: 'CLE', 66: 'PHX', 67: 'PBI', 68: 'ILM', 69: 'MIA', 70: 'AMA', 71: 'RIC', 72: 'CMH', 73: 'EWR', 74: 'BIL', 75: 'LYH', 76: 'ISP', 77: 'MSN', 78: 'MAF', 79: 'SMF', 80: 'TLH', 81: 'CRW', 82: 'APN', 83: 'DAL', 84: 'ATL', 85: 'BLI', 86: 'PSC', 87: 'LAN', 88: 'EUG', 89: 'BUF', 90: 'MFR', 91: 'HNL', 92: 'BZN', 93: 'TUS', 94: 'JAX', 95: 'STX', 96: 'LEX', 97: 'RSW', 98: 'VPS', 99: 'PWM', 100: 'EVV', 101: 'GSP', 102: 'LIT', 103: 'ROC', 104: 'MDW', 105: 'PNS', 106: 'ELP', 107: 'OAK', 108: 'SAT', 109: 'IAD', 110: 'SJU', 111: 'MHT', 112: 'ORF', 113: 'KOA', 114: 'SPI', 115: 'EYW', 116: 'AGS', 117: 'GSO', 118: 'BFL', 119: 'ORH', 120: 'ICT', 121: 'AVL', 122: 'MOB', 123: 'MEM', 124: 'ABE', 125: 'FWA', 126: 'SBP', 127: 'SGF', 128: 'MSO', 129: 'LGB', 130: 'DAY', 131: 'ANC', 132: 'TTN', 133: 'BUR', 134: 'RAP', 135: 'SRQ', 136: 'LIH', 137: 'LFT', 138: 'ATW', 139: 'JAN', 140: 'MFE', 141: 'FAT', 142: 'CVG', 143: 'BHM', 144: 'AVP', 145: 'PSP', 146: 'BTV', 147: 'GUM', 148: 'SGU', 149: 'PGD', 150: 'TUL', 151: 'SAV', 152: 'FLG', 153: 'STT', 154: 'MGM', 155: 'SCE', 156: 'CHA', 157: 'LBB', 158: 'MDT', 159: 'FAY', 160: 'AKN', 161: 'RDD', 162: 'SHV', 163: 'FAR', 164: 'BGR', 165: 'GEG', 166: 'YUM', 167: 'HSV', 168: 'OAJ', 169: 'STS', 170: 'ACV', 171: 'DSM', 172: 'MHK', 173: 'GJT', 174: 'CAE', 175: 'ITO', 176: 'MQT', 177: 'MYR', 178: 'DAB', 179: 'LCH', 180: 'TRI', 181: 'FNT', 182: 'SIT', 183: 'GRB', 184: 'GFK', 185: 'MLU', 186: 'BRO', 187: 'SBN', 188: 'JNU', 189: 'FCA', 190: 'SBA', 191: 'HRL', 192: 'FSD', 193: 'MLI', 194: 'JAC', 195: 'ELM', 196: 'CHO', 197: 'ECP', 198: 'GPT', 199: 'PIE', 200: 'EAU', 201: 'ADQ', 202: 'COU', 203: 'CWA', 204: 'TVC', 205: 'LWS', 206: 'ITH', 207: 'AZO', 208: 'CRP', 209: 'SFB', 210: 'BMI', 211: 'TYR', 212: 'MRY', 213: 'UIN', 214: 'JST', 215: 'HPN', 216: 'PAE', 217: 'BLV', 218: 'SUX', 219: 'MBS', 220: 'PIR', 221: 'LNK', 222: 'BTM', 223: 'MOT', 224: 'CMX', 225: 'ASE', 226: 'DRO', 227: 'PAH', 228: 'OME', 229: 'DLG', 230: 'KTN', 231: 'RFD', 232: 'PVU', 233: 'YAK', 234: 'ABY', 235: 'HTS', 236: 'CPR', 237: 'FSM', 238: 'MTJ', 239: 'ALW', 240: 'MLB', 241: 'DEC', 242: 'DLH', 243: 'HVN', 244: 'SAF', 245: 'BQN', 246: 'EWN', 247: 'GRK', 248: 'GRI', 249: 'XWA', 250: 'HLN', 251: 'TOL', 252: 'CAK', 253: 'LAW', 254: 'LRD', 255: 'GTF', 256: 'ERI', 257: 'LSE', 258: 'CMI', 259: 'BIS', 260: 'EGE', 261: 'FNL', 262: 'ROA', 263: 'PUB', 264: 'COD', 265: 'LBL', 266: 'ILG', 267: 'BGM', 268: 'SWF', 269: 'CLL', 270: 'PBG', 271: 'USA', 272: 'IMT', 273: 'GNV', 274: 'ACT', 275: 'CDC', 276: 'SBY', 277: 'ABI', 278: 'FLO', 279: 'ROW', 280: 'RIW', 281: 'ACY', 282: 'EKO', 283: 'BHB', 284: 'OWB', 285: 'RST', 286: 'LBE', 287: 'EAT', 288: 'PLN', 289: 'BFF', 290: 'LBF', 291: 'PHF', 292: 'OTH', 293: 'HHH', 294: 'GGG', 295: 'CSG', 296: 'SPN', 297: 'LAR', 298: 'CIU', 299: 'BQK', 300: 'PGV', 301: 'BRD', 302: 'PSE', 303: 'ESC', 304: 'DIK', 305: 'ATY', 306: 'DHN', 307: 'SHR', 308: 'SUN', 309: 'SMX', 310: 'PSM', 311: 'HIB', 312: 'TWF', 313: 'VCT', 314: 'GCC', 315: 'IAG', 316: 'CYS', 317: 'LWB', 318: 'ACK', 319: 'JMS', 320: 'LCK', 321: 'BPT', 322: 'PUW', 323: 'EAR', 324: 'PIB', 325: 'DRT', 326: 'SJT', 327: 'ABR', 328: 'JHM', 329: 'MBL', 330: 'DDC', 331: 'SCK', 332: 'PKB', 333: 'ART', 334: 'VLD', 335: 'JLN', 336: 'MCW', 337: 'PPG', 338: 'DVL', 339: 'TBN', 340: 'GUC', 341: 'RHI', 342: 'WRG', 343: 'GTR',  ...

# %%
dest_string_dict = ''
for row in dest_dict['mapping']:
    dest_string_dict += ("{")
    dest_string_dict += (f"'label': '{dest_dict['mapping'].index[row]}', 'value': {dest_dict['mapping'][row]}")
    dest_string_dict += ("}, ")

# %%
dest_string_dict
# Out:
# "{'label': 'CLE', 'value': 2}, {'label': 'MSP', 'value': 3}, {'label': 'BLI', 'value': 4}, {'label': 'LIH', 'value': 5}, {'label': 'PIT', 'value': 6}, {'label': 'BZN', 'value': 7}, {'label': 'PHX', 'value': 8}, {'label': 'DFW', 'value': 9}, {'label': 'HOU', 'value': 10}, {'label': 'ONT', 'value': 11}, {'label': 'MFR', 'value': 12}, {'label': 'JFK', 'value': 13}, {'label': 'DAL', 'value': 14}, {'label': 'DSM', 'value': 15}, {'label': 'DCA', 'value': 16}, {'label': 'LAX', 'value': 17}, {'label': 'LCH', 'value': 18}, {'label': 'MCI', 'value': 19}, {'label': 'MYR', 'value': 20}, {'label': 'PDX', 'value': 21}, {'label': 'RSW', 'value': 22}, {'label': 'DEN', 'value': 23}, {'label': 'MCO', 'value': 24}, {'label': 'SBA', 'value': 25}, {'label': 'TUS', 'value': 26}, {'label': 'SAN', 'value': 27}, {'label': 'LGA', 'value': 28}, {'label': 'EWR', 'value': 29}, {'label': 'TVC', 'value': 30}, {'label': 'PSP', 'value': 31}, {'label': 'SJU', 'value': 32}, {'label': 'ELP', 'value': 33}, {'label': 'DTW', 'value': 34}, {'label': 'SFO', 'value': 35}, {'label': 'SRQ', 'value': 36}, {'label': 'JAX', 'value': 37}, {'label': 'ATL', 'value': 38}, {'label': 'VLD', 'value': 39}, {'label': 'AUS', 'value': 40}, {'label': 'TLH', 'value': 41}, {'label': 'PIB', 'value': 42}, {'label': 'MKE', 'value': 43}, {'label': 'GTF', 'value': 44}, {'label': 'SJC', 'value': 45}, {'label': 'FAI', 'value': 46}, {'label': 'SMF', 'value': 47}, {'label': 'ORD', 'value': 48}, {'label': 'BNA', 'value': 49}, {'label': 'PNS', 'value': 50}, {'label': 'BWI', 'value': 51}, {'label': 'MIA', 'value': 52}, {'label': 'SGF', 'value': 53}, {'label': 'CMH', 'value': 54}, {'label': 'TPA', 'value': 55}, {'label': 'DAB', 'value': 56}, {'label': 'HPN', 'value': 57}, {'label': 'IND', 'value': 58}, {'label': 'PBI', 'value': 59}, {'label': 'RIC', 'value': 60}, {'label': 'SNA', 'value': 61}, {'label': 'FAR', 'value': 62}, {'label': 'STL', 'value': 63}, {'label': 'GEG', 'value': 64}, {'label': 'LAS', 'value': 65}, {'label': 'MFE', 'value': 66}, {'label': 'SAT', 'value': 67}, {'label': 'BHM', 'value': 68}, {'label': 'MHK', 'value': 69}, {'label': 'MGM', 'value': 70}, {'label': 'MSN', 'value': 71}, {'label': 'SEA', 'value': 72}, {'label': 'BUR', 'value': 73}, {'label': 'RDU', 'value': 74}, {'label': 'ITH', 'value': 75}, {'label': 'CHA', 'value': 76}, {'label': 'CVG', 'value': 77}, {'label': 'BOS', 'value': 78}, {'label': 'OAK', 'value': 79}, {'label': 'ABQ', 'value': 80}, {'label': 'MVY', 'value': 81}, {'label': 'RNO', 'value': 82}, {'label': 'CLT', 'value': 83}, {'label': 'PGD', 'value': 84}, {'label': 'CHS', 'value': 85}, {'label': 'FLL', 'value': 86}, {'label': 'KOA', 'value': 87}, {'label': 'PHL', 'value': 88}, {'label': 'PVD', 'value': 89}, {'label': 'GSP', 'value': 90}, {'label': 'HNL', 'value': 91}, {'label': 'TYS', 'value': 92}, {'label': 'PLN', 'value': 93}, {'label': 'MAF', 'value': 94}, {'label': 'SLC', 'value': 95}, {'label': 'MEM', 'value': 96}, {'label': 'CMI', 'value': 97}, {'label': 'MDT', 'value': 98}, {'label': 'MHT', 'value': 99}, {'label': 'SLN', 'value': 100}, {'label': 'BTR', 'value': 101}, {'label': 'CAK', 'value': 102}, {'label': 'STX', 'value': 103}, {'label': 'ACV', 'value': 104}, {'label': 'IAD', 'value': 105}, {'label': 'SFB', 'value': 106}, {'label': 'HLN', 'value': 107}, {'label': 'OKC', 'value': 108}, {'label': 'PWM', 'value': 109}, {'label': 'ABR', 'value': 110}, {'label': 'MDW', 'value': 111}, {'label': 'LGB', 'value': 112}, {'label': 'STT', 'value': 113}, {'label': 'BDL', 'value': 114}, {'label': 'MSY', 'value': 115}, {'label': 'SDF', 'value': 116}, {'label': 'LIT', 'value': 117}, {'label': 'BUF', 'value': 118}, {'label': 'FAT', 'value': 119}, {'label': 'MLU', 'value': 120}, {'label': 'OMA', 'value': 121}, {'label': 'SPS', 'value': 122}, {'label': 'ATW', 'value': 123}, {'label': 'STS', 'value': 124}, {'label': 'ICT', 'value': 125}, {'label': 'PSE', 'value': 126}, {'label': 'JLN', 'value': 127}, {'label': 'SYR', 'value': 128}, {'label': 'GRB', 'value': 129}, {'label': ...

# %%
dest_string2_dict = '{'
for row in dest_dict['mapping']:
    dest_string2_dict += (f"{dest_dict['mapping'][row]}: '{dest_dict['mapping'].index[row]}', ")

# %%
dest_dict = {2: 'ISP', 3: 'SEA', 4: 'CLT', 5: 'JAX', 6: 'TPA', 7: 'MCO', 8: 'MDW', 9: 'DTW', 10: 'MSY', 11: 'LAX', 12: 'DEN', 13: 'MCI', 14: 'BQN', 15: 'LGA', 16: 'BWI', 17: 'PSM', 18: 'AZA', 19: 'PHX', 20: 'DFW', 21: 'EWR', 22: 'ONT', 23: 'MKE', 24: 'SAT', 25: 'BOS', 26: 'ELM', 27: 'JFK', 28: 'LIH', 29: 'PBI', 30: 'MSP', 31: 'LAS', 32: 'DAL', 33: 'RIC', 34: 'ANC', 35: 'OAK', 36: 'CVG', 37: 'SAN', 38: 'CHS', 39: 'ELP', 40: 'MIA', 41: 'LGB', 42: 'HNL', 43: 'FLL', 44: 'IAD', 45: 'PVD', 46: 'OGG', 47: 'CHA', 48: 'SLC', 49: 'BUR', 50: 'PWM', 51: 'ATL', 52: 'PDX', 53: 'FAT', 54: 'SFO', 55: 'SMF', 56: 'AUS', 57: 'RSW', 58: 'STL', 59: 'CLE', 60: 'MEM', 61: 'PHL', 62: 'SJC', 63: 'HOU', 64: 'PNS', 65: 'SAV', 66: 'DCA', 67: 'IAH', 68: 'SNA', 69: 'SJU', 70: 'TUL', 71: 'BNA', 72: 'CMH', 73: 'SDF', 74: 'PSP', 75: 'MAF', 76: 'RNO', 77: 'TUS', 78: 'GFK', 79: 'ALB', 80: 'KOA', 81: 'ABQ', 82: 'BGR', 83: 'GTF', 84: 'RDU', 85: 'FSD', 86: 'BOI', 87: 'GRR', 88: 'OMA', 89: 'PIT', 90: 'SIT', 91: 'HPN', 92: 'IND', 93: 'BUF', 94: 'PGD', 95: 'PIE', 96: 'GEG', 97: 'BRW', 98: 'BDL', 99: 'SGF', 100: 'SFB', 101: 'PBG', 102: 'DSM', 103: 'STX', 104: 'ITO', 105: 'MLI', 106: 'ATW', 107: 'JAC', 108: 'MYR', 109: 'COS', 110: 'LCK', 111: 'CAK', 112: 'JAN', 113: 'BIL', 114: 'BHM', 115: 'ORF', 116: 'SRQ', 117: 'FWA', 118: 'OME', 119: 'PVU', 120: 'VPS', 121: 'MHT', 122: 'PIA', 123: 'MLB', 124: 'MTJ', 125: 'HRL', 126: 'MDT', 127: 'SYR', 128: 'OKC', 129: 'ROC', 130: 'STT', 131: 'SCK', 132: 'EUG', 133: 'CID', 134: 'BLI', 135: 'EYW', 136: 'SWF', 137: 'ORH', 138: 'AMA', 139: 'GSO', 140: 'AVL', 141: 'RFD', 142: 'LIT', 143: 'SBN', 144: 'ILM', 145: 'EGE', 146: 'FNT', 147: 'HDN', 148: 'CDV', 149: 'SPI', 150: 'SBA', 151: 'BIS', 152: 'AVP', 153: 'RAP', 154: 'ECP', 155: 'ABE', 156: 'LBB', 157: 'ACK', 158: 'TTN', 159: 'JNU', 160: 'HYA', 161: 'ICT', 162: 'GPT', 163: 'ACY', 164: 'ROA', 165: 'PSE', 166: 'BZN', 167: 'CRP', 168: 'DAY', 169: 'TYS', 170: 'CAE', 171: 'SHV', 172: 'IAG', 173: 'MSN', 174: 'BTR', 175: 'DAB', 176: 'MFE', 177: 'ADQ', 178: 'FAI', 179: 'TLH', 180: 'USA', 181: 'GJT', 182: 'GUC', 183: 'BLV', 184: 'MSO', 185: 'GUM', 186: 'BTV', 187: 'FAR', 188: 'KTN', 189: 'TOL', 190: 'BET', 191: 'EVV', 192: 'HTS', 193: 'GSP', 194: 'CKB', 195: 'STC', 196: 'IDA', 197: 'LBE', 198: 'LEX', 199: 'GRI', 200: 'GST', 201: 'OGS', 202: 'PSC', 203: 'MFR', 204: 'BMI', 205: 'OGD', 206: 'AGS', 207: 'FCA', 208: 'XNA', 209: 'LFT', 210: 'SPN', 211: 'MOT', 212: 'HGR', 213: 'TVC', 214: 'AKN', 215: 'PSG', 216: 'SMX', 217: 'MOB', 218: 'STS', 219: 'LRD', 220: 'MVY', 221: 'OTZ', 222: 'HSV', 223: 'MRY', 224: 'PHF', 225: 'BKG', 226: 'WRG', 227: 'SCC', 228: 'CHO', 229: 'OWB', 230: 'TRI', 231: 'YAK', 232: 'PPG', 233: 'DLH', 234: 'GNV', 235: 'FAY', 236: 'CRW', 237: 'YNG', 238: 'GRB', 239: 'DLG', 240: 'ADK', 241: 'LNK', 242: 'ASE', 243: 'DRO', 244: 'MKG', 245: 'SGU', 246: 'BFL', 247: 'OTH', 248: 'CPR', 249: 'ITH', 250: 'SBP', 251: 'SCE', 252: 'RST', -2: 'nan', 252: 'RST'}

# %%
dest_string2_dict[2]
# Out:
# ':'

# %%
for x in dest_dict:
  print(dest_dict[x])
# Out:
# ISP
# SEA
# CLT
# JAX
# TPA
# MCO
# MDW
# DTW
# MSY
# LAX
# DEN
# MCI
# BQN
# LGA
# BWI
# PSM
# AZA
# PHX
# DFW
# EWR
# ONT
# MKE
# SAT
# BOS
# ELM
# JFK
# LIH
# PBI
# MSP
# LAS
# DAL
# RIC
# ANC
# OAK
# CVG
# SAN
# CHS
# ELP
# MIA
# LGB
# HNL
# FLL
# IAD
# PVD
# OGG
# CHA
# SLC
# BUR
# PWM
# ATL
# PDX
# FAT
# SFO
# SMF
# AUS
# RSW
# STL
# CLE
# MEM
# PHL
# SJC
# HOU
# PNS
# SAV
# DCA
# IAH
# SNA
# SJU
# TUL
# BNA
# CMH
# SDF
# PSP
# MAF
# RNO
# TUS
# GFK
# ALB
# KOA
# ABQ
# BGR
# GTF
# RDU
# FSD
# BOI
# GRR
# OMA
# PIT
# SIT
# HPN
# IND
# BUF
# PGD
# PIE
# GEG
# BRW
# BDL
# SGF
# SFB
# PBG
# DSM
# STX
# ITO
# MLI
# ATW
# JAC
# MYR
# COS
# LCK
# CAK
# JAN
# BIL
# BHM
# ORF
# SRQ
# FWA
# OME
# PVU
# VPS
# MHT
# PIA
# MLB
# MTJ
# HRL
# MDT
# SYR
# OKC
# ROC
# STT
# SCK
# EUG
# CID
# BLI
# EYW
# SWF
# ORH
# AMA
# GSO
# AVL
# RFD
# LIT
# SBN
# ILM
# EGE
# FNT
# HDN
# CDV
# SPI
# SBA
# BIS
# AVP
# RAP
# ECP
# ABE
# LBB
# ACK
# TTN
# JNU
# HYA
# ICT
# GPT
# ACY
# ROA
# PSE
# BZN
# CRP
# DAY
# TYS
# CAE
# SHV
# IAG
# MSN
# BTR
# DAB
# MFE
# ADQ
# FAI
# TLH
# USA
# GJT
# GUC
# BLV
# MSO
# GUM
# BTV
# FAR
# KTN
# TOL
# BET
# EVV
# HTS
# GSP
# CKB
# STC
# IDA
# LBE
# LEX
# GRI
# GST
# OGS
# PSC
# MFR
# BMI
# OGD
# AGS
# FCA
# XNA
# LFT
# SPN
# MOT
# HGR
# TVC
# AKN
# PSG
# SMX
# MOB
# STS
# LRD
# MVY
# OTZ
# HSV
# MRY
# PHF
# BKG
# WRG
# SCC
# CHO
# OWB
# TRI
# YAK
# PPG
# DLH
# GNV
# FAY
# CRW
# YNG
# GRB
# DLG
# ADK
# LNK
# ASE
# DRO
# MKG
# SGU
# BFL
# OTH
# CPR
# ITH
# SBP
# SCE
# RST
# nan

# %%
airline_dict
# Out:
# {'col': 'OpCarrier',
#  'mapping': 99      1
#  DL      2
#  AA      3
#  G4      4
#  HA      5
#  WN      6
#  UA      7
#  OO      8
#  F9      9
#  9E     10
#  C5     11
#  YX     12
#  NK     13
#  AS     14
#  OH     15
#  ZW     16
#  MX     17
#  B6     18
#  MQ     19
#  YV     20
#  PT     21
#  QX     22
#  G7     23
#  SY     24
#  XP     25
#  3M     26
#  --     27
#  9K     28
#  LF     29
#  AC     30
#  9X     31
#  KG     32
#  BR     33
#  4B     34
#  SK     35
#  NaN    -2
#  dtype: int64,
#  'data_type': CategoricalDtype(categories=['--', '3M', '4B', '7H', '99', '9E', '9K', '9X', 'AA', 'AC',
#                    'AS', 'B6', 'BR', 'C5', 'DL', 'F9', 'FI', 'G4', 'G7', 'HA',
#                    'KG', 'LF', 'LH', 'MQ', 'MX', 'NK', 'OH', 'OO', 'OZ', 'PT',
#                    'QX', 'SK', 'SY', 'UA', 'WN', 'XP', 'YV', 'YX', 'ZW'],
#  , ordered=False)}

# %%
origin_options = flights['Origin'].unique()
miles_string = '{'

for origin in origin_options:
    origin_data = flights[flights['Origin'] == origin]
    unique_dest = origin_data['Dest'].unique()
    for dest in unique_dest:
        dest_data = origin_data[origin_data['Dest'] == dest].reset_index()
        miles_string += f"'{origin}>{dest}':{int(dest_data['MktDistance'][0])},"
miles_string = miles_string[0:-2]
miles_string += '}'

# %%
miles_string
# Out:
# "{'BOS>BUF':482,'BOS>BZN':2082,'BOS>CHS':828,'BOS>CLE':604,'BOS>ORD':919,'BOS>CLT':729,'BOS>CMH':663,'BOS>CVG':769,'BOS>DCA':399,'BOS>IAD':423,'BOS>DEN':1805,'BOS>ABQ':2154,'BOS>COS':1878,'BOS>FCA':2556,'BOS>HNL':5168,'BOS>JAC':2212,'BOS>MSO':2484,'BOS>SBA':2720,'BOS>DFW':1572,'BOS>IAH':1796,'BOS>SHV':1762,'BOS>DTW':688,'BOS>EGE':1925,'BOS>EYW':1396,'BOS>FLL':1265,'BOS>GRR':805,'BOS>GSO':645,'BOS>GSP':794,'BOS>HHH':887,'BOS>LIH':5264,'BOS>MFE':1916,'BOS>TUS':2536,'BOS>IND':845,'BOS>SFO':2812,'BOS>JAX':1020,'BOS>LAS':3398,'BOS>LAX':2664,'BOS>SAT':4224,'BOS>ITO':5104,'BOS>EWR':200,'BOS>MCI':1292,'BOS>MCO':1137,'BOS>SLC':3428,'BOS>MEM':1146,'BOS>MIA':1285,'BOS>MKE':925,'BOS>MSN':999,'BOS>MSP':1208,'BOS>MSY':1367,'BOS>MTJ':1995,'BOS>MYR':750,'BOS>ATL':1067,'BOS>OGG':5104,'BOS>PHX':2360,'BOS>SGF':1357,'BOS>ORF':484,'BOS>PBI':1223,'BOS>PDX':2634,'BOS>PIT':519,'BOS>RDU':616,'BOS>SAV':909,'BOS>RIC':477,'BOS>ROC':446,'BOS>RSW':1268,'BOS>SAN':2624,'BOS>SDF':842,'BOS>SEA':2602,'BOS>BUR':3092,'BOS>GEG':3498,'BOS>MFR':3094,'BOS>RNO':2956,'BOS>SMF':2852,'BOS>SJU':1808,'BOS>STT':1876,'BOS>VQS':1847,'BOS>SNA':2634,'BOS>SRQ':1234,'BOS>STL':1072,'BOS>SYR':395,'BOS>TPA':1197,'BOS>XNA':1331,'BOS>ABE':572,'BOS>AUS':1710,'BOS>AVL':783,'BOS>AVP':602,'BOS>BFD':620,'BOS>BNA':955,'BOS>LFT':1813,'BOS>CAE':814,'BOS>CAK':664,'BOS>CHO':490,'BOS>OKC':1749,'BOS>CKB':564,'BOS>DAY':781,'BOS>MBS':1271,'BOS>CRP':2010,'BOS>ERI':672,'BOS>HDN':1995,'BOS>HSV':1009,'BOS>LCH':1730,'BOS>ILM':736,'BOS>ITH':663,'BOS>JST':533,'BOS>KOA':5204,'BOS>EAU':1647,'BOS>LNS':515,'BOS>LWB':589,'BOS>MDT':507,'BOS>PHL':548,'BOS>PNS':1217,'BOS>ROA':590,'BOS>ASE':3676,'BOS>SCE':546,'BOS>SHD':504,'BOS>TYS':833,'BOS>AEX':1787,'BOS>AMA':2114,'BOS>BHM':2160,'BOS>BRO':1905,'BOS>BTR':1850,'BOS>CLL':1671,'BOS>ECP':2168,'BOS>ELP':2264,'BOS>GPT':1973,'BOS>GRK':1763,'BOS>GUM':9304,'BOS>HOB':2098,'BOS>HRL':1892,'BOS>ICT':2140,'BOS>JAN':1948,'BOS>JLN':2092,'BOS>LBB':2056,'BOS>LIT':1971,'BOS>LRD':1898,'BOS>MAF':2026,'BOS>MEI':2019,'BOS>MLU':1859,'BOS>MOB':2024,'BOS>DRO':2572,'BOS>OMA':2378,'BOS>ONT':2932,'BOS>PIB':1969,'BOS>PSP':2866,'BOS>MRY':3308,'BOS>SJC':3204,'BOS>TUL':2026,'BOS>VCT':1720,'BOS>VPS':2124,'BOS>EUG':3360,'BOS>FAT':2820,'BOS>RDD':3112,'BOS>RDM':3336,'BOS>SBP':2768,'BOS>SAF':4000,'BOS>ACV':3198,'BOS>ATW':1028,'BOS>ATY':1374,'BOS>AZO':989,'BOS>BOI':2304,'BOS>CGI':1206,'BOS>CHA':1367,'BOS>CID':1063,'BOS>CMX':1227,'BOS>COU':1182,'BOS>CRW':1283,'BOS>CWA':1080,'BOS>DEC':1023,'BOS>ANC':4160,'BOS>GJT':1967,'BOS>CVN':2032,'BOS>DLH':1264,'BOS>DSM':1166,'BOS>EAR':1450,'BOS>EVV':1139,'BOS>BQN':3172,'BOS>FAR':1424,'BOS>FNT':1090,'BOS>FOD':1192,'BOS>FSD':1330,'BOS>FWA':1024,'BOS>GRB':1041,'BOS>LAN':1046,'BOS>LEX':1190,'BOS>LNK':1333,'BOS>MBL':1046,'BOS>MKG':986,'BOS>MLI':1006,'BOS>GFK':1485,'BOS>PAH':1209,'BOS>PIA':997,'BOS>RAP':1647,'BOS>SBN':951,'BOS>EKO':2316,'BOS>IDA':2304,'BOS>SLN':1426,'BOS>SPI':1041,'BOS>SUN':2208,'BOS>SUX':1303,'BOS>TBN':1236,'BOS>TVC':1091,'BOS>UIN':1089,'BOS>BFL':2942,'BOS>LNY':5176,'BOS>OTH':3116,'BOS>STS':2770,'BOS>CEZ':2031,'BOS>HOU':1798,'BOS>LGB':2608,'BOS>MDW':1337,'BOS>DAL':1565,'BOS>RST':1185,'BOS>SJT':1791,'BOS>SPS':1699,'BOS>SWO':1787,'BOS>TLH':1114,'BOS>TOL':1080,'BOS>TXK':1772,'BOS>TYR':1664,'BOS>BWI':369,'BOS>STX':2376,'BOS>OAK':2954,'BOS>HLN':2348,'BOS>AGS':1089,'BOS>DAB':1312,'BOS>JFK':187,'BOS>LGA':184,'BOS>FAI':4972,'BOS>FAY':1277,'BOS>CYS':1844,'BOS>DVL':2392,'BOS>ESC':938,'BOS>FLG':2256,'BOS>FSM':1789,'BOS>GCC':2068,'BOS>GNV':1116,'BOS>GTF':2376,'BOS>GUC':1906,'BOS>HIB':1298,'BOS>HYS':2052,'BOS>IMT':976,'BOS>JMS':2328,'BOS>LAR':1867,'BOS>LAW':1702,'BOS>LSE':1048,'BOS>LWS':2566,'BOS>MCW':1208,'BOS>MHK':1993,'BOS>BIS':2270,'BOS>MOT':2358,'BOS>MQT':1424,'BOS>PIH':2256,'BOS>PIR':2140,'BOS>PLN':875,'BOS>PRC':2312,'BOS>PSC':2668,'BOS>PUB':1863,'BOS>RHI':1456,'BOS>RIW':2050,'BOS>RKS':2014,'BOS>ALB':343,'BOS>BGR':201,'BOS>DHN':1241,'BOS>ABI':1731,'BOS>BMI':983,'BOS>DBQ':1014,'BOS>PHF':481,'BOS>SBY':387,'BOS>TRI':1173,'BOS>ADQ':4196,'BOS>ALW':2708,'BOS>AKN':42 ...

# %%
# saving the model 
import pickle 
pickle_out = open("regressor.pkl", mode = "wb") 
pickle.dump(model, pickle_out) 
pickle_out.close()

# %%
def predict(ItinID, MktID, MktCoupons, Quarter, Origin, OriginWac, Dest, DestWac, Miles, ContiguousUSA, NumTicketsOrdered, AirlineCompany):

  #ContiguousUSA = boolean dictionary

  #Miles = dictionary

    # Make dataframe from the inputs
    df = pd.DataFrame(
        data=[[ItinID, MktID, MktCoupons, Quarter, Origin, OriginWac, Dest, DestWac, MktDistance, Passengers, OpCarrier]], 
        columns=['ItinID', 'MktID', 'MktCoupons', 'Quarter', 'Origin', 'OriginWac', 'Dest', 'DestWac','MktDistance', 'Passengers', 'OpCarrier']
    )
    
    pred = model.predict(df)[0]

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'n_estimators': [100, 80, 60, 55, 51, 45],  
              'max_depth': [7, 8],
              'reg_lambda' :[0.26, 0.25, 0.2]
             }
                
grid = GridSearchCV(xg.XGBRFRegressor(), param_grid, refit = True, verbose = 3, n_jobs=-1) #
regr_trans = TransformedTargetRegressor(regressor=grid, transformer=QuantileTransformer(output_distribution='normal'))

# fitting the model for grid search 
grid_result=regr_trans.fit(x_train_encoded, y_train)
best_params=grid_result.regressor_.best_params_
print(best_params)

#using best params to create and fit model
best_model = xg.XGBRFRegressor(max_depth=best_params["max_depth"], n_estimators=best_params["n_estimators"], reg_lambda=best_params["reg_lambda"])
regr_trans = TransformedTargetRegressor(regressor=best_model, transformer=QuantileTransformer(output_distribution='normal'))
regr_trans.fit(x_train_encoded, y_train)
yhat = regr_trans.predict(x_val_encoded)

#evaluate metrics
r2_score(y_val, yhat), mean_absolute_error(y_val, yhat), np.sqrt(mean_squared_error(y_val, yhat))

# %%
from sklearn.ensemble import GradientBoostingRegressor
import lightgbm as lgbm
import xgboost as xg
from sklearn.preprocessing import QuantileTransformer, quantile_transform
from sklearn.compose import TransformedTargetRegressor

#generic function to fit model and return metrics for every algorithm
def boost_models(x):
    #transforming target variable through quantile transformer
    regr_trans = TransformedTargetRegressor(regressor=x, transformer=QuantileTransformer(output_distribution='normal'))
    regr_trans.fit(x_train_encoded, y_train)
    yhat = regr_trans.predict(x_val_encoded)
    algoname= x.__class__.__name__
    return algoname, round(r2_score(y_val, yhat),3), round(mean_absolute_error(y_val, yhat),2), round(np.sqrt(mean_squared_error(y_val, yhat)),2)

algo=[GradientBoostingRegressor(), lgbm.LGBMRegressor(), xg.XGBRFRegressor()]
score=[]
for a in algo:
    score.append(boost_models(a))

 #Collate all scores in a table
pd.DataFrame(score, columns=['Model', 'Score', 'MAE', 'RMSE'])

# %%
head = 10
for model in regressors[:head]:
    start = time()
    model.fit(x_train_encoded, y_train)
    train_time = time() - start
    start = time()
    y_pred = model.predict(x_val_encoded)
    predict_time = time()-start    
    print(model)
    print("\tTraining time: %0.3fs" % train_time)
    print("\tPrediction time: %0.3fs" % predict_time)
    print("\tExplained variance:", explained_variance_score(y_val, y_pred))
    print("\tMean absolute error:", mean_absolute_error(y_val, y_pred))
    print("\tR2 score:", r2_score(y_val, y_pred))
    print()
